# %% [markdown]
# # Determine Business Objective
# ### Background
# Build the best multiple regression model that you can for the purpose of predicting head injury severity, using all the other variables as the predictors
# ### Business Objective
# ### Success Criteria
# Reducing the severity of injury
# # Asses the situation
# ### Resource Inventory
# ### Risk and Contigency
# ### Terminology
# # Determining Data Mining Objective
# ### DM success criteria
# # Produce Project Criteria
# ### initial assesment of tools and techniques
# # Data Understanding
# ### Collect initial data
# ### Describe data
# summary statistics (mean,median,mode,1st quartile,etc.)
# ### Explore data
# ### Verify data quality
# # Data prepration
# ### Rotational data selection for inclusion and exclusion
# fields to be included, no. of rows needed to be selected
# ### Data Cleaning report
# no. of incorrect values, no. of missing fields, no. of blank fields (data cleaning reports)
# ### Construct data
# Derived fields
# ### Format  and cimbine data
# integrate the data
# # Modling
# ### Select model techniques
# assumptions
# ### Generate test design
# how much will be for testing
# ### Build model
# set model parameters
# ### Asses model
# # Evaluation
# ### Evaluate results
# asses of data mining result w.r.t business criteria
# ### Approve Model
# ### Review process
# ### Determine next steps
# list of possible action
# # Deployment
# ### Plan deployment
# ### Maintenance
# ### Produce final report
# ### Review project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df = pd.read_csv("Crash.dat",sep="\t")

# %%
df.head()
# Out:
#         MAKE            MODEL                      CARID  \
# 0  Acura      Integra          Acura Integra
# 1  Acura      Integra RS       Acura Integra RS
# 2  Acura      Legend LS        Acura Legend LS
# 3  Audi       80               Audi 80
# 4  Audi       100              Audi 100
#
#                        CARID_YR HEAD_INJ CHEST_IN LLEG_INJ RLEG_INJ DRIV_PAS  \
# 0  Acura Integra 87                  599       35      791      262   Driver
# 1  Acura Integra RS 90               585              1545     1301   Driver
# 2  Acura Legend LS 88                435       50      926      708   Driver
# 3  Audi 80 89                        600       49      168     1871   Driver
# 4  Audi 100 89                       185       35      998      894   Driver
#
#            PROTECT  DOORS  YEAR  WEIGHT  SIZE  SIZE2 PROTECT2
# 0  manual belts     2        87    2350  lt        2        1
# 1  Motorized belts  4        90    2490  lt        2        2
# 2  d airbag         4        88    3280  med       3        4
# 3  manual belts     4        89    2790  comp      1        1
# 4  d airbag         4        89    3100  med       3        4

# %%
df.describe()
# Out:
#              YEAR       WEIGHT       SIZE2
# count  352.000000   352.000000  352.000000
# mean    88.914773  2930.340909    3.573864
# std      1.411636   627.134938    2.428510
# min     87.000000  1590.000000    1.000000
# 25%     88.000000  2487.500000    2.000000
# 50%     89.000000  2855.000000    3.000000
# 75%     90.000000  3292.000000    6.000000
# max     91.000000  5619.000000    8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 16 columns):
# MAKE        352 non-null object
# MODEL       352 non-null object
# CARID       352 non-null object
# CARID_YR    352 non-null object
# HEAD_INJ    352 non-null object
# CHEST_IN    352 non-null object
# LLEG_INJ    352 non-null object
# RLEG_INJ    352 non-null object
# DRIV_PAS    352 non-null object
# PROTECT     352 non-null object
# DOORS       352 non-null object
# YEAR        352 non-null int64
# WEIGHT      352 non-null int64
# SIZE        352 non-null object
# SIZE2       352 non-null int64
# PROTECT2    352 non-null object
# dtypes: int64(3), object(13)
# memory usage: 44.1+ KB

# %%
df.dtypes
# Out:
# MAKE        object
# MODEL       object
# CARID       object
# CARID_YR    object
# HEAD_INJ    object
# CHEST_IN    object
# LLEG_INJ    object
# RLEG_INJ    object
# DRIV_PAS    object
# PROTECT     object
# DOORS       object
# YEAR         int64
# WEIGHT       int64
# SIZE        object
# SIZE2        int64
# PROTECT2    object
# dtype: object

# %%
df['HEAD_INJ']=pd.to_numeric(df['HEAD_INJ'].str.extract('(\d+)'))
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['HEAD_INJ'].fillna(865,inplace=True)

# %%
df['HEAD_INJ']=df['HEAD_INJ'].astype('int64')

# %%
df['CHEST_IN']=pd.to_numeric(df['CHEST_IN'].str.extract('(\d+)'))
df['CHEST_IN'].fillna(47,inplace=True)
df['CHEST_IN']=df['CHEST_IN'].astype('int64')
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['LLEG_INJ']=pd.to_numeric(df['LLEG_INJ'].str.extract('(\d+)'))
df['LLEG_INJ'].fillna(1027,inplace=True)
df['LLEG_INJ']=df['LLEG_INJ'].astype('int64')
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['RLEG_INJ']=pd.to_numeric(df['RLEG_INJ'].str.extract('(\d+)'))
df['RLEG_INJ'].fillna(718,inplace=True)
df['RLEG_INJ']=df['RLEG_INJ'].astype('int64')
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['DOORS']=pd.to_numeric(df['DOORS'].str.extract('(\d+)'))
df['DOORS'].fillna(2,inplace=True)
df['DOORS']=df['DOORS'].astype('int64')
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['PROTECT2']=pd.to_numeric(df['PROTECT2'].str.extract('(\d+)'))
df['PROTECT2'].fillna(4,inplace=True)
df['PROTECT2']=df['PROTECT2'].astype('int64')
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df['YEAR'].fillna(89,inplace=True)

# %%
df['WEIGHT'].fillna(2930,inplace=True)

# %%
df['SIZE2'].fillna(3,inplace=True)

# %%
df.dtypes
# Out:
# MAKE        object
# MODEL       object
# CARID       object
# CARID_YR    object
# HEAD_INJ     int64
# CHEST_IN     int64
# LLEG_INJ     int64
# RLEG_INJ     int64
# DRIV_PAS    object
# PROTECT     object
# DOORS        int64
# YEAR         int64
# WEIGHT       int64
# SIZE        object
# SIZE2        int64
# PROTECT2     int64
# dtype: object

# %%
import statsmodels.api as sm
# Out:
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5ed6312ad2b2> in <module>()
#       1 import statsmodels.api as sm
# ----> 2 x= df[df.columns-'HEAD_INJ']
#       3 y=df['HEAD_INJ']
#
# F:\Anaconda3-5.1.0\lib\site-packages\pandas\core\indexes\base.py in __sub__(self, other)
#    2161     def __sub__(self, other):
#    2162         raise TypeError("cannot perform __sub__ with this index type: "
# -> 2163                         "{typ}".format(typ=type(self)))
#    2164
#    2165     def __and__(self, other):
#
# TypeError: cannot perform __sub__ with this index type: <class 'pandas.core.indexes.base.Index'>

# %%
df.columns
# Out:
# Index(['MAKE', 'MODEL', 'CARID', 'CARID_YR', 'HEAD_INJ', 'CHEST_IN',
#        'LLEG_INJ', 'RLEG_INJ', 'DRIV_PAS', 'PROTECT', 'DOORS', 'YEAR',
#        'WEIGHT', 'SIZE', 'SIZE2', 'PROTECT2'],
#       dtype='object')

# %%
x= df[['MAKE', 'MODEL','CHEST_IN','LLEG_INJ', 'RLEG_INJ', 'DRIV_PAS', 'DOORS', 'YEAR','WEIGHT','SIZE2', 'PROTECT2']]
y=df['HEAD_INJ']

# %%
y.head()
# Out:
# 0    599
# 1    585
# 2    435
# 3    600
# 4    185
# Name: HEAD_INJ, dtype: object

# %%
x.head()
# Out:
#         MAKE            MODEL CHEST_IN LLEG_INJ RLEG_INJ DRIV_PAS  DOORS  \
# 0  Acura      Integra               35      791      262   Driver  2
# 1  Acura      Integra RS                   1545     1301   Driver  4
# 2  Acura      Legend LS             50      926      708   Driver  4
# 3  Audi       80                    49      168     1871   Driver  4
# 4  Audi       100                   35      998      894   Driver  4
#
#    YEAR  WEIGHT  SIZE2 PROTECT2
# 0    87    2350      2        1
# 1    90    2490      2        2
# 2    88    3280      3        4
# 3    89    2790      1        1
# 4    89    3100      3        4

# %%
x_1=sm.add_constant(x)
results=sm.OLS(y,x_1).fit()
results.params
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-dc8cf0df3e6c> in <module>()
#       1 x_1=sm.add_constant(x)
# ----> 2 results=sm.OLS(y,x_1).fit()
#       3 results.params
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     629                  **kwargs):
#     630         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 631                                   hasconst=hasconst, **kwargs)
#     632         if "weights" in self._init_keys:
#     633             self._init_keys.remove("weights")
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     524             weights = weights.squeeze()
#     525         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 526                                   weights=weights, hasconst=hasconst, **kwargs)
#     527         nobs = self.exog.shape[0]
#     528         weights = self.weights
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#      93     """
#      94     def __init__(self, endog, exog, **kwargs):
# ---> 95         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#      96         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#      97
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      61         hasconst = kwargs.pop('hasconst', None)
#      62         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 63                                       **kwargs)
#      64         self.k_constant = self.data.k_constant
#      65         self.exog = self.data.exog
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      86
#      87     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 88         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      89         # kwargs arrays could have changed, easier to just attach here
#      90         for key in kwargs:
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     628     klass = handle_data_class_factory(endog, exog)
#     629     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 630                  **kwargs)
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
#
# F:\Anaconda3-5.1.0\lib\site-packages\statsmodels\base\data.py in _convert_endog_exog(self, endog, exog)
#     469         exog = exog if exog is None else np.asarray(exog)
#     470         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 471             raise ValueError("Pandas data cast to numpy dtype of object. "
#     472                              "Check input data with np.asarray(data).")
#     473         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %% [markdown]
# * Which company make had highest head injury count
# * Which company make had lowest head injury count
# * WHch year car make had the highest head injury
# * WHch year car make had the lowest head injury
# * TYpes of protection have influence on ehich type of injury
# * whihc TYpes of protection have highest influence on head injury
# * whihc TYpes of protection have least influence on head injury
# * Significance of door on  various injury
# * Significance of door on  head injury
# * Driver had more injury or passenger (line graph plot of driver and passenger based on various factors)
# * Over the years have the car make company have improved in safety measures or not.
# * Over the years have the car make company have improved in safety  of head injury measures or not.
# * Over the years have the injury safety improved ?
# * Over the years have the head injury safety improved ? And which injury has declined?
# * Does car size affect head injury or other inury?
# * no. of cars model of a single company and thier saftey measure as improved over the year
# * Does other injury help prevent other injury
# * which company make is the safest
# * which company model is the safest
# * which year is the safest

# %%
df
# Out:
#           MAKE            MODEL                      CARID  \
# 0    Acura      Integra          Acura Integra
# 1    Acura      Integra RS       Acura Integra RS
# 2    Acura      Legend LS        Acura Legend LS
# 3    Audi       80               Audi 80
# 4    Audi       100              Audi 100
# 5    BMW        325i             BMW 325i
# 6    Buick      Century          Buick Century
# 7    Buick      Elect. Park Ave  Buick Elect. Park Ave
# 8    Buick      Le Sabre         Buick Le Sabre
# 9    Buick      Regal            Buick Regal
# 10   Cadillac   De Ville         Cadillac De Ville
# 11   Chevrolet  Astro            Chevrolet Astro
# 12   Chevrolet  Astro            Chevrolet Astro
# 13   Chevrolet  Beretta          Chevrolet Beretta
# 14   Chevrolet  Beretta GT       Chevrolet Beretta GT
# 15   Chevrolet  Camaro           Chevrolet Camaro
# 16   Chevrolet  Camaro           Chevrolet Camaro
# 17   Chevrolet  Caprice          Chevrolet Caprice
# 18   Chevrolet  Caprice          Chevrolet Caprice
# 19   Chevrolet  Cavalier         Chevrolet Cavalier
# 20   Chevrolet  Corsica          Chevrolet Corsica
# 21   Chevrolet  Corsica          Chevrolet Corsica
# 22   Chevrolet  C-1500           Chevrolet C-1500
# 23   Chevrolet  G-20 Beauville   Chevrolet G-20 Beauville
# 24   Chevrolet  G-20             Chevrolet G-20
# 25   Chevrolet  Lumina           Chevrolet Lumina
# 26   Chevrolet  Suburban         Chevrolet Suburban
# 27   Chevrolet  S-10 Blazer 4X4  Chevrolet S-10 Blazer 4X4
# 28   Chevrolet  S-10 Blazer 4X4  Chevrolet S-10 Blazer 4X4
# 29   Chevrolet  S-10 Blazer 4X4  Chevrolet S-10 Blazer 4X4
# ..         ...              ...                        ...
# 322  Renault    Medallion        Renault Medallion
# 323  Saab       900S             Saab 900S
# 324  Saab       9000             Saab 9000
# 325  Saturn     SL2              Saturn SL2
# 326  Subaru     GL               Subaru GL
# 327  Subaru     Justy DL         Subaru Justy DL
# 328  Subaru     Legacy           Subaru Legacy
# 329  Suzuki     Sidekick 4x4     Suzuki Sidekick 4x4
# 330  Suzuki     Sidekick 4x4     Suzuki Sidekick 4x4
# 331  Toyota     4-Runner 4x4     Toyota 4-Runner 4x4
# 332  Toyota     Camry            Toyota Camry
# 333  Toyota     Celica           Toyota Celica
# 334  Toyota     Corolla Fx       Toyota Corolla Fx
# 335  Toyota     Corolla          Toyota Corolla
# 336  Toyota     Corolla          Toyota Corolla
# 337  Toyota     Cressida         Toyota Cressida
# 338  Toyota     Pickup           Toyota Pickup
# 339  Toyota     Pickup           Toyota Pickup
# 340  Toyota     Pickup 4x4       Toyota Pickup 4x4
# 341  Toyota     Previa           Toyota Previa
# 342  Toyota     Tercel           Toyota Tercel
# 343  Toyota     Tercel           Toyota Tercel
# 344  Toyota     Van              Toyota Van
# 345  Volkswage  Fox              Volkswagen Fox
# 346  Volkswage  Fox              Volkswagen Fox
# 347  Volkswage  Fox              Volkswagen Fox
# 348  Volkswage  Passat           Volkswagen Passat
# 349  Volkswage  Vanagon GL       Volkswagen Vanagon GL
# 350  Volvo      740 GLE          Volvo 740 GLE
# 351  Yugo       GV               Yugo GV
#
#                          CARID_YR  HEAD_INJ  CHEST_IN  LLEG_INJ  RLEG_INJ  \
# 0    Acura Integra 87                   599        35       791       262
# 1    Acura Integra RS 90                585        47      1545      1301
# 2    Acura Legend LS 88                 435        50       926       708
# 3    Audi 80 89                         600        49       168      1871
# 4    Audi 100 89                        185        35       998       894
# 5    BMW 325i 90                       1036        56       865       718
# 6    Buick Century 91                   815        47      1340       315
# 7    Buick Elect. Park Ave 88          1467        54       712      1366
# 8    Buick Le Sabre 90                  865        35      1049       908
# 9    Buick Regal 88                     880        50       996       642
# 10   Cadillac De Ville 90               423        39       541      1629
# 11   Chevrolet Astro 88                1603        72      1572       700
# 12   Chevrolet Astro 89                1849        64      2737      1043
# 13   Chevrolet Beretta 91               343        37       659       523
